# %%
pip install speech_recognition
# Out:
# Note: you may need to restart the kernel to use updated packages.
# ERROR: Could not find a version that satisfies the requirement speech_recognition (from versions: none)
# ERROR: No matching distribution found for speech_recognition

# %%
 pip uptodate speech_recognition
# Out:
# Note: you may need to restart the kernel to use updated packages.
# ERROR: unknown command "uptodate"

# %%
import datetime
import pyttsx3
import speech_recognition as sr
#import cv2
#import numpy as np
import wikipedia
import webbrowser
import os




engine = pyttsx3.init('sapi5')
voices = engine.getProperty('voices')
print(voices[0].id)
engine.setProperty('voice',voices[0].id)



def speak(audio):
    engine.say(audio)
    engine.runAndWait()

def wishMe():
    hour = int(datetime.datetime.now().hour )
    if hour >= 0 and hour<12:
        speak("good morning boss!")
    elif hour >= 12 and hour <18:
        speak("goo afternoon sir!")
    else:
        speak("good evening boss!")

    speak(" i am jarvis .... , your system")


def takeCommand():
    '''it taskes microphone input from the user and return string outpu7t'''
    r = sr.Recognizer()

    with sr.Microphone() as sourceid:
        # print(f"helo  {r.listen(source)}")
        print("  Jarvis Listening....")
        r.pause_threshold = 1

        print("hiii in listening")
        audio = r.listen(sourceid)
        # audio = "hii jarvish"
        print("with is close")

    try:
        print("Recognizing.....")

        query = r.recognize_google(audio, language='en-IN')
        print(query)
        print("hiiii......")

    except Exception as e:
        print(e)
        print("say that again please....")
        return "None"

    return query

# def myface():
#
#     face_cascade = cv2.CascadeClassifire('haarcascade_frontalface_default')
#     cap = cv2.VideoCapture(0)

if __name__ == "__main__":
    speak("    hellow           boss")
    wishMe()
    query = takeCommand().lower()


    if 1:


        # Logic for executing tasks based on query
        print(query)
        if 'wikipedia' in query:
            speak('Searching Wikipedia....')
            print("serching...1")
            print(query)
            query1 = query.replace("wikipedia", "")
            print("serching...2")
            print(query1)
            results = wikipedia.summary(query, sentences=3)

            speak("According to wikipedia")
            print(results)
            speak(results)

        elif 'open youtube' in query:
            webbrowser.open("youtube.com")

        elif 'open google' in query:
            webbrowser.open("google.com")

        elif 'play music' in query:

            print('play song')
            str_split = query.split()
            print(str_split)
            counter_split = 1
            count = 0
            music_dir = 'D:\\03 06 2020\\media1\\audio\\music'
            songs = os.listdir(music_dir)

            for split_word in str_split:
                print(counter_split)
                if split_word == 'music':
                    user_song_split = str_split[counter_split:]
                    print(user_song_split)
                    result_user_song = ''

                    for element in user_song_split:
                        string_new = str(element)
                        result_user_song += (string_new + "_")

                    print(result_user_song)
                    break

                else:
                    print("split again")
                    counter_split += 1


            #print(songs)

            for song_name in songs :
                # print(song_name)
                # print('Fulll...')
                list_size = len(songs)
                print(list_size)
                play_song_name = song_name.lower()
                print(play_song_name)

                if result_user_song in play_song_name:
                    print(song_name)
                    print(count)
                    os.startfile(os.path.join(music_dir, songs[count]))
                    break
                else:
                    count += 1
                    if count > list_size:
                        print("your song is not in play list")
                        break

            # os.startfile(os.path.join(music_dir, songs[0]))

        elif 'the time' in query:
            strtime = datetime.datetime.now().strftime("%H:%M:%S")
            speak(f"Sir, the time is {strtime}")

        elif 'open pycham' in query:
            codepath = "C:\\Program Files\\JetBrains\\PyCharm Community Edition 2020.2.2\\bin\\pycharm64.exe"
            os.startfile(codepath)

        elif 'quiet' in query:
            speak("ok boss")
            exit()

        elif 'shutdown' in query:
            speak("Do you want to shutdown your computer")
            os.system("shutdown /s /t 30")

        elif 'restart' in query:
            print("restart your system")
            os.system("shutdown /r /t 30")

        elif 'jarvis' in query:
            print("jarvis")
            # takeCommand()

    # myface()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-4-790a4424c44e> in <module>
#       1 import datetime
#       2 import pyttsx3
# ----> 3 import speech_recognition as sr
#       4 #import cv2
#       5 #import numpy as np
#
# ModuleNotFoundError: No module named 'speech_recognition'
